# %% [markdown]
# # 0.tensorflow_version

# %%
import tensorflow as tf
tf.__version__

# %% [markdown]
# # 1.資料預處理Cifar CNN

# %%
from tensorflow.keras.datasets import cifar10

(X_train_image, y_train_label), (X_test_image, y_test_label) = cifar10.load_data()

# %% [markdown]
# 檔案儲存-->複製網址(正上方https://colab.research.google.com/.............) -->工具-->設定-->Custom snippet notebook URL貼上並儲存-->建立新筆記本-->點選右側程式碼片段-->選擇需要的片段按下插入
